# %% [markdown]
# <a href="https://colab.research.google.com/github/mokymok/notebooks/blob/main/data_viz_libraries_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pl
import plotly.graph_objects as go
import plotly.express as px
import altair as alt
import folium as fol
import bokeh as bok
import holoviews as hv

df = pd.read_csv("https://raw.githubusercontent.com/axrd/datasets/master/tipdata.csv", index_col=0)
df

# %%
df = pd.read_csv("https://raw.githubusercontent.com/axrd/datasets/master/tipdata.csv", index_col=0)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.plot.scatter(
    x="total_bill",
    y="tip"
    )

# %%
df.boxplot(
    column="total_bill",
    by="day"
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df.boxplot(
    column="tip",
    by="day"
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df.boxplot(
    column="size", 
    by="day"
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df["subtotal"]=df.total_bill-df.tip
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  subtotal
# 0         16.99  1.01  Female     No   Sun  Dinner     2     15.98
# 1         10.34  1.66    Male     No   Sun  Dinner     3      8.68
# 2         21.01  3.50    Male     No   Sun  Dinner     3     17.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2     20.37
# 4         24.59  3.61  Female     No   Sun  Dinner     4     20.98
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     23.11
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     25.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     20.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2     16.07
# 243       18.78  3.00  Female     No  Thur  Dinner     2     15.78
#
# [244 rows x 8 columns]

# %%
df.plot.hexbin(
    x="subtotal",
    y="tip",
    gridsize=25
)

# %%
df.boxplot(
    column="total_bill",
    by="sex"
)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df["tip_percentage"]=(df.tip/df.subtotal)*100
df
# Out:
#      total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0         16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 1         10.34  1.66    Male     No  ...  Dinner    3      8.68       19.124424
# 2         21.01  3.50    Male     No  ...  Dinner    3     17.51       19.988578
# 3         23.68  3.31    Male     No  ...  Dinner    2     20.37       16.249386
# 4         24.59  3.61  Female     No  ...  Dinner    4     20.98       17.206864
# ..          ...   ...     ...    ...  ...     ...  ...       ...             ...
# 239       29.03  5.92    Male     No  ...  Dinner    3     23.11       25.616616
# 240       27.18  2.00  Female    Yes  ...  Dinner    2     25.18        7.942812
# 241       22.67  2.00    Male    Yes  ...  Dinner    2     20.67        9.675859
# 242       17.82  1.75    Male     No  ...  Dinner    2     16.07       10.889857
# 243       18.78  3.00  Female     No  ...  Dinner    2     15.78       19.011407
#
# ...

# %%
df.boxplot(
    column="tip_percentage",
    by="sex"
)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df.loc[df['tip_percentage']>100]
# Out:
#      total_bill   tip   sex smoker  day    time  size  subtotal  tip_percentage
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2       2.1      245.238095

# %%
df.boxplot(
    column="tip",
    by="sex",
    sym=''
)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df.boxplot(
    column="tip_percentage",
    by="sex",
    sym=''
)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df.boxplot(
    column="total_bill",
    by="sex",
    sym=''
)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
df.plot.scatter(
    x='tip',
    y="tip_percentage"
)

# %%
df.drop(
    [172],
    axis=0,
    inplace=True
)
df.loc[df['tip_percentage']>100]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, subtotal, tip_percentage]
# Index: []

# %%
df.plot.scatter(
    x='tip',
    y="tip_percentage"
)

# %%
df.head(15)
# Out:
#     total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0        16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 1        10.34  1.66    Male     No  ...  Dinner    3      8.68       19.124424
# 2        21.01  3.50    Male     No  ...  Dinner    3     17.51       19.988578
# 3        23.68  3.31    Male     No  ...  Dinner    2     20.37       16.249386
# 4        24.59  3.61  Female     No  ...  Dinner    4     20.98       17.206864
# 5        25.29  4.71    Male     No  ...  Dinner    4     20.58       22.886297
# 6         8.77  2.00    Male     No  ...  Dinner    2      6.77       29.542097
# 7        26.88  3.12    Male     No  ...  Dinner    4     23.76       13.131313
# 8        15.04  1.96    Male     No  ...  Dinner    2     13.08       14.984709
# 9        14.78  3.23    Male     No  ...  Dinner    2     11.55       27.965368
# 10       10.27  1.71    Male     No  ...  Dinner    2      8.56       19.976636
# ...

# %%
df['total_bill'].plot.hist(
    title='bill',
    bins=40
    )

# %%
df['tip_percentage'].plot.hist(
    title='tip percentages',
    bins=40,
    alpha=.5
    )

# %% [markdown]
# **The following is a script for a histogram showing the correlation of tip percentages (based on subtotal of the bill) and sex.**

# %%
#define a new dataframe with the sex and tip_percentage columns  
df_stp = pd.DataFrame(
    {
        'sex_stp':df['sex'],
        'tip_percentage_stp':df['tip_percentage']

    }
)

#define two more DataFrames that separate sexes prior to recombining in a
#third new DataFrame that we'll then use for plotting the histogram
df_stp.sort_values('sex_stp')
df_stp_f = df_stp.loc[df_stp['sex_stp']=='Female']
df_stp_m = df_stp.loc[df_stp['sex_stp']=='Male']

#modify first new df (df_stp_f) to have 1-step int-value indexes
df_stp_f.index = pd.RangeIndex(start=0, stop=87, step=1)
df_stp_f.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)

#modify second new df (df_stp_m) to have 1-step int-value indexes
df_stp_m.index = pd.RangeIndex(start=0, stop=156, step=1)
df_stp_m.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)

#define the final DataFrame that will be used to plot the histogram
df_tp = pd.DataFrame(
    {
        'mt':df_stp_m['tip_percentage_stp'],
        'ft':df_stp_f['tip_percentage_stp']
    }
)

#plot the histogram  
df_tp.plot.hist(
    title='tip percentage among men and women',
    bins=70,
    alpha=.75
)

# %% [markdown]
# **A slightly modified version is below, evening out the amount of data from both men and women, since there are about twice as many entries for men as women.**

# %%
df_tp_mod = df_tp.dropna()
df_tp_mod.plot.hist(    
    title='modified tip percentage among men and women',
    bins=100,
    alpha=.75
)

# %%
df
# Out:
#      total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0         16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 1         10.34  1.66    Male     No  ...  Dinner    3      8.68       19.124424
# 2         21.01  3.50    Male     No  ...  Dinner    3     17.51       19.988578
# 3         23.68  3.31    Male     No  ...  Dinner    2     20.37       16.249386
# 4         24.59  3.61  Female     No  ...  Dinner    4     20.98       17.206864
# ..          ...   ...     ...    ...  ...     ...  ...       ...             ...
# 239       29.03  5.92    Male     No  ...  Dinner    3     23.11       25.616616
# 240       27.18  2.00  Female    Yes  ...  Dinner    2     25.18        7.942812
# 241       22.67  2.00    Male    Yes  ...  Dinner    2     20.67        9.675859
# 242       17.82  1.75    Male     No  ...  Dinner    2     16.07       10.889857
# 243       18.78  3.00  Female     No  ...  Dinner    2     15.78       19.011407
#
# ...

# %%
df_time = df.sort_values('time')

# %%
df_time
# Out:
#      total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0         16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 152       17.26  2.74    Male     No  ...  Dinner    3     14.52       18.870523
# 153       24.55  2.00    Male     No  ...  Dinner    4     22.55        8.869180
# 154       19.77  2.00    Male     No  ...  Dinner    4     17.77       11.254924
# 155       29.85  5.14  Female     No  ...  Dinner    5     24.71       20.801295
# ..          ...   ...     ...    ...  ...     ...  ...       ...             ...
# 127       14.52  2.00  Female     No  ...   Lunch    2     12.52       15.974441
# 128       11.38  2.00  Female     No  ...   Lunch    2      9.38       21.321962
# 129       22.82  2.18    Male     No  ...   Lunch    3     20.64       10.562016
# 193       15.48  2.02    Male    Yes  ...   Lunch    2     13.46       15.007429
# 121       13.42  1.68  Female     No  ...   Lunch    2     11.74       14.310051
#
# ...

# %% [markdown]
# **The following script shows the correlation between time of day (lunch and dinner) and the total amount presented on the bill.**

# %%
#define a new dataframe with the time and total_bill columns  
df_ttb = pd.DataFrame(
    {
        'time_ttb':df['time'],
        'total_bill_ttb':df['total_bill']

    }
)

#define two more DataFrames that separate times prior to recombining in a
#third new DataFrame that we'll then use for plotting the scatter plot
df_ttb.sort_values('time_ttb')
df_ttb_d = df_ttb.loc[df_ttb['time_ttb']=='Dinner']
df_ttb_l = df_ttb.loc[df_ttb['time_ttb']=='Lunch']

#modify first new df (df_ttb_d) to have 1-step int-value indexes
df_ttb_d.index = pd.RangeIndex(start=0, stop=175, step=1)
df_ttb_d.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)

#modify second new df (df_ttb_l) to have 1-step int-value indexes
df_ttb_l.index = pd.RangeIndex(start=0, stop=68, step=1)
df_ttb_l.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)

#define the final DataFrame that will be used to plot the histogram
df_ttbf = pd.DataFrame(
    {
        'dinner':df_ttb_d['total_bill_ttb'],
        'lunch':df_ttb_l['total_bill_ttb']
    }
)

#plot the histogram  
df_ttbf.plot.hist(
    title='total bill based on meal time',
    bins=70,
    alpha=.59
)

# %% [markdown]
# *This is where I found out about Seaborn, another library for Python that visualizes data on top of Pandas - often times in less lines of script.*

# %% [markdown]
# **The following is a script detailing the frequency of smokers given the time of day, utilizing Seaborn with Pandas.**

# %%
sns.set_theme(style='darkgrid')

#plot the counts graph from seaborn  
df_tsf = sns.countplot(
    x='time',
    hue='smoker',
    data=df
)

# %% [markdown]
# **The following script is a remake of the tip percentage vs. sex graph I wrote above, this time utilizing Seaborn and graphing a swarmplot rather than a histogram...**

# %%
df_stp_sb = sns.catplot(
    x='sex',
    y='tip_percentage',
    data=df,
    kind='swarm'
)

# %% [markdown]
# **...and in a catplot...**

# %%
df_new_2 = sns.catplot(
    x="sex",
    y="tip_percentage",
    hue="time",      
    kind="violin", 
    inner="stick", 
    split=True,
    palette="pastel", 
    data=df
)

# %% [markdown]
# **You can even plot things like the total bill based on day and sex...**

# %%
df_new = sns.catplot(
    x="day",
    y="total_bill",
    hue="sex",      
    kind="violin", 
    inner="stick", 
    split=True,
    palette="pastel", 
    data=df
)

# %%
df
# Out:
#      total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0         16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 1         10.34  1.66    Male     No  ...  Dinner    3      8.68       19.124424
# 2         21.01  3.50    Male     No  ...  Dinner    3     17.51       19.988578
# 3         23.68  3.31    Male     No  ...  Dinner    2     20.37       16.249386
# 4         24.59  3.61  Female     No  ...  Dinner    4     20.98       17.206864
# ..          ...   ...     ...    ...  ...     ...  ...       ...             ...
# 239       29.03  5.92    Male     No  ...  Dinner    3     23.11       25.616616
# 240       27.18  2.00  Female    Yes  ...  Dinner    2     25.18        7.942812
# 241       22.67  2.00    Male    Yes  ...  Dinner    2     20.67        9.675859
# 242       17.82  1.75    Male     No  ...  Dinner    2     16.07       10.889857
# 243       18.78  3.00  Female     No  ...  Dinner    2     15.78       19.011407
#
# ...

# %% [markdown]
# **...or something like this, showcasing the non-correlation between size of party and tip percentage...**

# %%
df_new_1 = sns.catplot(
    x="size",
    y="tip_percentage",
    hue="time",      
    kind="violin", 
    inner="stick", 
    split=True,
    palette="pastel", 
    data=df
)

# %% [markdown]
# **Altair, another library, is great for visualizing geometries, both 2d and 3d, and is also built on the same Pandas DataFrames I've been using.**
#
# **Below, though, is a couple examples of what you can do with it (not using the current dataset.)**
#
# **The first is graticules (the latitudinal and longitudinal lines you see on a globe) from an orthographic projection.**

# %%
data_grat = alt.graticule(step=[15, 15])

alt.Chart(data_grat).mark_geoshape(stroke='black').project(
    'orthographic',
    rotate=[0, -45, 0]
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **Likewise, we can turn this "sphere" any which way just by editing the "rotate" args.**
#
# **We can also change the "step" args to increase or decrease the distance between the lines.**
#
# The projection style can be one of the following:
# 'albers',
# 'albersUsa',
# 'azimuthalEqualArea',
# 'azimuthalEquidistant',
# 'conicConformal',
# 'conicEqualArea',
# 'conicEquidistant',
# 'equalEarth',
# 'equirectangular',
# 'gnomonic',
# 'identity',
# 'mercator',
# 'naturalEarth1',
# 'orthographic',
# 'stereographic',
# 'transverseMercator'.

# %%
data_1 = alt.graticule(step=[47, 6])

alt.Chart(data_1).mark_geoshape(stroke='blue').project(
    'equalEarth',
    rotate=[14, 125, 72]
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data_1).mark_geoshape(stroke='blue').project(
    'orthographic',
    rotate=[14, 125, 72]
)
# Out:
# alt.Chart(...)

# %%
df
# Out:
#      total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0         16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 1         10.34  1.66    Male     No  ...  Dinner    3      8.68       19.124424
# 2         21.01  3.50    Male     No  ...  Dinner    3     17.51       19.988578
# 3         23.68  3.31    Male     No  ...  Dinner    2     20.37       16.249386
# 4         24.59  3.61  Female     No  ...  Dinner    4     20.98       17.206864
# ..          ...   ...     ...    ...  ...     ...  ...       ...             ...
# 239       29.03  5.92    Male     No  ...  Dinner    3     23.11       25.616616
# 240       27.18  2.00  Female    Yes  ...  Dinner    2     25.18        7.942812
# 241       22.67  2.00    Male    Yes  ...  Dinner    2     20.67        9.675859
# 242       17.82  1.75    Male     No  ...  Dinner    2     16.07       10.889857
# 243       18.78  3.00  Female     No  ...  Dinner    2     15.78       19.011407
#
# ...

# %%
chart_df = alt.Chart(df)

# %%
chart_dfj = chart_df.mark_point().encode(
    x='day',
    y="total_bill"
)
chart_dfj
# Out:
# alt.Chart(...)

# %% [markdown]
# **Although Altair is great for visualizing geometries, its main purpose is actually to streamline conversion of plot specifications to a JSON string that complies with the Vega-Lite schema.  In order to see exactly what Altair is sending to Vega-Lite, we can use the "to_json()" method.**

# %%
print(chart_dfj.to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",
#   "config": {
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400
#     }
#   },
#   "data": {
#     "name": "data-77fb1035d20908deb443a56b16d809bb"
#   },
#   "datasets": {
#     "data-77fb1035d20908deb443a56b16d809bb": [
#       {
#         "day": "Sun",
#         "sex": "Female",
#         "size": 2,
#         "smoker": "No",
#         "subtotal": 15.979999999999999,
#         "time": "Dinner",
#         "tip": 1.01,
#         "tip_percentage": 6.320400500625782,
#         "total_bill": 16.99
#       },
#       {
#         "day": "Sun",
#         "sex": "Male",
#         "size": 3,
#         "smoker": "No",
#         "subtotal": 8.68,
#         "time": "Dinner",
#         "tip": 1.66,
#         "tip_percentage": 19.12442396313364,
#         "total_bill": 10.34
#       },
#       {
#         "day": "Sun",
#         "sex": "Male",
#         "size": 3,
#         "smoker": "No",
# ...

# %% [markdown]
# **Although this is its main purpose, it's also great for making interactive charts and graphs that allow you to see your data in different ways.**

# %%
brush = alt.selection_interval()

chart_int = alt.Chart(df).mark_point().encode(
    y='total_bill:Q',
    color=alt.condition(brush, 'sex:N', alt.value('lightgray'))
).properties(
    width=600,
    height=600
).add_selection(
    brush
)

chart_int.encode(x='tip:Q') | chart_int.encode(x='tip_percentage:Q')
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# **However, if we wanted to do a 3-dimensional graph or chart, we would use Plotly, *another* library that is great for data visualization.**

# %%
fig = px.scatter_3d(df, x='tip', y='total_bill', z='tip_percentage',
              color='sex')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="51e8eee3-dcbb-48b2-8535-5f49bd6880b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51e8eee3-dcbb-48b2-8535-5f49bd6880b4")) {
#                     Plotly.newPlot(
#                         '51e8eee3-dcbb-48b2-8535-5f49bd6880b4',
# ...

# %%
df420 = px.data.iris()
fig = px.scatter_3d(df420, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a1d86258-8502-457b-9a95-c7086d0c23a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a1d86258-8502-457b-9a95-c7086d0c23a5")) {
#                     Plotly.newPlot(
#                         'a1d86258-8502-457b-9a95-c7086d0c23a5',
# ...

# %% [markdown]
# **Plotly can also be used in conjunction with Folium to create some very interesting maps.**

# %%
mountbruno = fol.Map(location=[45.54982138369651, -73.31695889218297])
mountbruno
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=[go.Surface(z=z_data.values)])
fig.update_traces(contours_z=dict(show=True, usecolormap=True,
                                  highlightcolor="limegreen", project_z=True))
fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  scene_camera_eye=dict(x=1.87, y=0.88, z=-0.64),
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="98bc68a2-72e2-44ea-8d5b-6a4617eb44ed" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("98bc68a2-72e2-44ea-8d5b-6a4617eb44ed")) {
#                     Plotly.newPlot(
#                         '98bc68a2-72e2-44ea-8d5b-6a4617eb44ed',
# ...

# %% [markdown]
# Note:  I have yet to figure out a way to overlay a topographical graph like the above over the Folium map.
#
# It may be as simple as pulling a CSV for contour lines that have been overlain on the Folium map into a new DataFrame, then appending the frame with the Z-axis data for the elevation map and putting that on top of the Folium map, though the z data would already be there, as it's foundational for having the contour lines to begin with.
#
#
#
# Another note to investigate:  Exporting Rhino curves as points in a CSV format, reading them as a DataFrame, and building a topography from that.  It should be relatively simple and would allow for actual quantitative analysis of the landscape.

# %%
dfC = pd.read_csv("https://raw.githubusercontent.com/rashida048/Datasets/master/census.csv", error_bad_lines=False)

# %%
dfC
# Out:
#       SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 0         40       3         6  ...     1.383282     1.724718    0.712594
# 1         50       3         6  ...    -2.722002     2.592270   -2.187333
# 2         50       3         6  ...    22.727626    20.317142   18.293499
# 3         50       3         6  ...    -7.167664    -3.978583  -10.543299
# 4         50       3         6  ...    -5.403729     0.754533    1.107861
# ...      ...     ...       ...  ...          ...          ...         ...
# 3188      50       4         8  ...    -5.295460   -14.075283  -14.070195
# 3189      50       4         8  ...    21.160658    16.308671    1.520747
# 3190      50       4         8  ...    -7.521840   -14.740608  -12.606351
# 3191      50       4         8  ...    -2.250385   -18.020168    1.441961
# 3192      50       4         8  ...    12.372583     1.533635    6.935294
#
# [3193 rows x 100 columns]

# %%
fig = px.scatter_3d(dfC, x='COUNTY', y='CENSUS2010POP', z='RDEATH2011',
              color='STNAME')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c53fa677-9521-49ca-b6b8-92f6e1951ccc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c53fa677-9521-49ca-b6b8-92f6e1951ccc")) {
#                     Plotly.newPlot(
#                         'c53fa677-9521-49ca-b6b8-92f6e1951ccc',
# ...

# %%
dfC_k = dfC.loc[dfC['STNAME']=='Kansas']
dfC_k.index = pd.RangeIndex(start=0, stop=106, step=1)
dfC_k.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)
dfC_k.drop(axis=0, index=0, inplace=True)
dfC_k
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      SUMLEV  REGION  DIVISION  ...  RNETMIG2013  RNETMIG2014 RNETMIG2015
# 1        50       2         4  ...   -15.058076   -11.000000  -12.954075
# 2        50       2         4  ...    -8.633824     4.580444  -10.328339
# 3        50       2         4  ...    -6.090279   -14.159185   -6.993220
# 4        50       2         4  ...    12.469338   -13.490036   -6.602703
# 5        50       2         4  ...    -6.514777    -8.887426   -7.284634
# ..      ...     ...       ...  ...          ...          ...         ...
# 101      50       2         4  ...   -17.238347    -3.549561   -4.988420
# 102      50       2         4  ...   -20.781568   -12.365468   -7.850381
# ...

# %%
fig_k = px.scatter_3d(dfC_k, x='CENSUS2010POP', y='DEATHS2010', z='POPESTIMATE2015',
              color='CTYNAME')
fig_k.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="623a163a-8478-49ed-b8ca-c3c6a65a49d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("623a163a-8478-49ed-b8ca-c3c6a65a49d5")) {
#                     Plotly.newPlot(
#                         '623a163a-8478-49ed-b8ca-c3c6a65a49d5',
# ...

# %% [markdown]
# **Going back to Pandas and basic Python, I wanted to try to start automating some of the data-wrangling that goes into the script I wrote earlier for plotting histograms based on two specific columns of data.**

# %%
#define a new dataframe with the sex and tip_percentage columns  
df_stp = pd.DataFrame(
    {
        'sex_stp':df['sex'],
        'tip_percentage_stp':df['tip_percentage']

    }
)

#define two more DataFrames that separate sexes prior to recombining in a
#third new DataFrame that we'll then use for plotting the histogram
df_stp.sort_values('sex_stp')
df_stp_f = df_stp.loc[df_stp['sex_stp']=='Female']
df_stp_m = df_stp.loc[df_stp['sex_stp']=='Male']

#modify first new df (df_stp_f) to have 1-step int-value indexes
df_stp_f.index = pd.RangeIndex(start=0, stop=87, step=1)
df_stp_f.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)

#modify second new df (df_stp_m) to have 1-step int-value indexes
df_stp_m.index = pd.RangeIndex(start=0, stop=156, step=1)
df_stp_m.rename(index=int).index
pd.Index(
    [0, 1, 2], 
    dtype='object'
)

#define the final DataFrame that will be used to plot the histogram
df_tp = pd.DataFrame(
    {
        'mt':df_stp_m['tip_percentage_stp'],
        'ft':df_stp_f['tip_percentage_stp']
    }
)

#plot the histogram  
df_tp.plot.hist(
    title='tip percentage among men and women',
    bins=70,
    alpha=.75
)

# %%
def index( df_name_2, df_cloumn, ele_len ):
  df_name_2.index = pd.RangeIndex(start=0, stop=ele_len, step=1)
  df_name_2.rename(index=int).index
  pd.Index(
      [0,1,2],
      dtype='object'
  )

# %%
index(df_stp_f, 'sex_stp', 87)

# %%
#define a new dataframe with the sex and tip_percentage columns  
df_stp = pd.DataFrame(
    {
        'sex_stp':df['sex'],
        'tip_percentage_stp':df['tip_percentage']

    }
)

#define two more DataFrames that separate sexes prior to recombining in a
#third new DataFrame that we'll then use for plotting the histogram
df_stp.sort_values('sex_stp')
df_stp_f = df_stp.loc[df_stp['sex_stp']=='Female']
df_stp_m = df_stp.loc[df_stp['sex_stp']=='Male']

#modify first new df (df_stp_f) to have 1-step int-value indexes
index(df_stp_f, 'sex_stp', 87)

#modify second new df (df_stp_m) to have 1-step int-value indexes
index(df_stp_m, 'sex_stp', 156)

#define the final DataFrame that will be used to plot the histogram
df_tp = pd.DataFrame(
    {
        'mt':df_stp_m['tip_percentage_stp'],
        'ft':df_stp_f['tip_percentage_stp']
    }
)

#plot the histogram  
df_tp.plot.hist(
    title='tip percentage among men and women',
    bins=70,
    alpha=.75
)

# %%
def newdf( origcol1, origcol2, newcol1, newcol2, dfname, dataname ):
  data_name={
          newcol1:df[origcol1],
          newcol2:df[origcol2]
      }
  dfname = pd.DataFrame(data_name)
  return dfname

# %%
df
# Out:
#      total_bill   tip     sex smoker  ...    time size  subtotal  tip_percentage
# 0         16.99  1.01  Female     No  ...  Dinner    2     15.98        6.320401
# 1         10.34  1.66    Male     No  ...  Dinner    3      8.68       19.124424
# 2         21.01  3.50    Male     No  ...  Dinner    3     17.51       19.988578
# 3         23.68  3.31    Male     No  ...  Dinner    2     20.37       16.249386
# 4         24.59  3.61  Female     No  ...  Dinner    4     20.98       17.206864
# ..          ...   ...     ...    ...  ...     ...  ...       ...             ...
# 239       29.03  5.92    Male     No  ...  Dinner    3     23.11       25.616616
# 240       27.18  2.00  Female    Yes  ...  Dinner    2     25.18        7.942812
# 241       22.67  2.00    Male    Yes  ...  Dinner    2     20.67        9.675859
# 242       17.82  1.75    Male     No  ...  Dinner    2     16.07       10.889857
# 243       18.78  3.00  Female     No  ...  Dinner    2     15.78       19.011407
#
# ...

# %%
df_new_5 = newdf('sex','tip_percentage', 's_stp', 't_stp', 'df_new_4', 'data_4')
# Out:
#       s_stp      t_stp
# 0    Female   6.320401
# 1      Male  19.124424
# 2      Male  19.988578
# 3      Male  16.249386
# 4    Female  17.206864
# ..      ...        ...
# 239    Male  25.616616
# 240  Female   7.942812
# 241    Male   9.675859
# 242    Male  10.889857
# 243  Female  19.011407
#
# [243 rows x 2 columns]

# %%
df_new_5
# Out:
#       s_stp      t_stp
# 0    Female   6.320401
# 1      Male  19.124424
# 2      Male  19.988578
# 3      Male  16.249386
# 4    Female  17.206864
# ..      ...        ...
# 239    Male  25.616616
# 240  Female   7.942812
# 241    Male   9.675859
# 242    Male  10.889857
# 243  Female  19.011407
#
# [243 rows x 2 columns]

# %%
#define a new dataframe with the sex and tip_percentage columns  
df_new_6 = newdf('sex','tip_percentage', 's_stp', 't_stp', 'df_new_6', 'data_6')

#define two more DataFrames that separate sexes prior to recombining in a
#third new DataFrame that we'll then use for plotting the histogram
df_stp.sort_values('sex_stp')
df_stp_f = df_stp.loc[df_stp['sex_stp']=='Female']
df_stp_m = df_stp.loc[df_stp['sex_stp']=='Male']

#modify first new df (df_stp_f) to have 1-step int-value indexes
index(df_stp_f, 'sex_stp', 87)

#modify second new df (df_stp_m) to have 1-step int-value indexes
index(df_stp_m, 'sex_stp', 156)

#define the final DataFrame that will be used to plot the histogram
df_tp = pd.DataFrame(
    {
        'mt':df_stp_m['tip_percentage_stp'],
        'ft':df_stp_f['tip_percentage_stp']
    }
)

#plot the histogram  
df_tp.plot.hist(
    title='tip percentage among men and women',
    bins=70,
    alpha=.75
)
