# %% [markdown]
# <a href="https://colab.research.google.com/github/mokymok/notebooks/blob/main/assembly_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install convert2PHP
# Out:
# ...
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
mov $1, %eax
mov $1, %edi
mov $o1, %rsi
mov $2, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o2, %rsi
mov $2, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o4, %rsi
mov $2, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o7, %rsi
mov $2, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o8, %rsi
mov $2, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o11, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o13, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o14, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $fb, %rsi
mov $10, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o16, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o17, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall


mov $1, %eax
mov $1, %edi
mov $o19, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o22, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o23, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o26, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o28, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o29, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $fb, %rsi
mov $10, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o31, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o32, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall


mov $1, %eax
mov $1, %edi
mov $o34, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o37, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o38, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o41, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o43, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o44, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $fb, %rsi
mov $10, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o46, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o47, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall


mov $1, %eax
mov $1, %edi
mov $o49, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o52, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o53, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o56, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o58, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o59, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $fb, %rsi
mov $10, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o61, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o62, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall


mov $1, %eax
mov $1, %edi
mov $o64, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o67, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o68, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o71, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o73, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o74, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $fb, %rsi
mov $10, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o76, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o77, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall


mov $1, %eax
mov $1, %edi
mov $o79, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o82, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o83, %rsi
mov $2, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o86, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o88, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o89, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $fb, %rsi
mov $10, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o91, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o92, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall


mov $1, %eax
mov $1, %edi
mov $o94, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $b, %rsi
mov $5, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $o97, %rsi
mov $3, %edx
syscall

mov $1, %eax
mov $1, %edi
mov $o98, %rsi
mov $3, %edx
syscall

mov $1, %eax 
mov $1, %edi 
mov $f, %rsi 
mov $5, %edx 
syscall

mov $1, %eax
mov $1, %edi
mov $final, %rsi
mov $5, %edx
syscall
